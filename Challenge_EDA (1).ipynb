# %% [markdown]
# # Sesión 3: EDA con DataFrames y Series

# %% [markdown]
# ## Objetivo
#
#  El objetivo de esta sesión es realizar un EDA sin visualización usando Pandas de Python.

# %% [markdown]
# ## Leer datos en `pandas`

# %% [markdown]
# Una forma popular de guardar datos es en archivos .csv y luego leer esos archivos en Python usando Pandas. Los archivos .csv son archivos de texto plano (o sin formato) que almacenan los datos en forma de tablas, separando los valores de las columnas usando comas.
#
# Para leer un archivo .csv en `pandas` primero debes importar la libreria, (por convención, se usa el alias `pd`), luego llamas a la función `read_csv()`:
#
# ~~~python
# import pandas as pd
# pd.read_csv("path/to/file.csv")
# ~~~
#
# En este challenge, utilizaremos los datos venta de una tienda en linea, que puedes descargar [aquí](https://www.kaggle.com/kyanyoga/sample-sales-data/version/1)

# %% [markdown]
# **1. Veamos las primeras 5 filas de nuestros datos usando **`.head()`**:

# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/ruta')
# Out:
# Mounted at /content/ruta

# %%
dfventas=pd.read_csv('/content/ruta/MyDrive/Clase #1 Machine Learning/sales_data_sample.csv',encoding="latin1")
dfventas.head(5)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  ...  CONTACTFIRSTNAME  DEALSIZE
# 0        10107               30  ...              Kwai     Small
# 1        10121               34  ...              Paul     Small
# 2        10134               41  ...            Daniel    Medium
# 3        10145               45  ...             Julie    Medium
# 4        10159               49  ...             Julie    Medium
#
# [5 rows x 25 columns]

# %% [markdown]
# ## Pregunta:
# *  ¿Qué tipo de información contiene el archivo?
#
# Un Dataset de 2823 filas y 25 columnas que contiene las Ventas (posiblemente de juguetes) mensuales entre los años 2003 y 2005 de una compañia.

# %%
dfventas.info()
dfventas.describe().T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# **2. Veamos las últimas 27 filas de nuestros datos usando **`.tail()`**:

# %%
dfventas.tail(27)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  ...  CONTACTFIRSTNAME  DEALSIZE
# 2796        10415               42  ...              Sean     Small
# 2797        10105               25  ...             Jytte     Small
# 2798        10117               50  ...              Eric     Small
# 2799        10129               32  ...               Ann     Small
# 2800        10142               39  ...           Valarie     Small
# 2801        10153               50  ...             Diego    Medium
# 2802        10167               38  ...             Maria     Small
# 2803        10177               40  ...             Jesus     Small
# 2804        10185               28  ...            Wing C     Small
# 2805        10197               42  ...           Eduardo     Small
# 2806        10208               42  ...              Mary     Small
# 2807        10222               36  ...           Valarie     Small
# 2808        10232               24  ...             Helen     Small
# ...

# %% [markdown]
# **3. Veamos la columna COSTUMERNAME usando Pandas Series**

# %%
dfventas.CUSTOMERNAME
# Out:
# 0              Land of Toys Inc.
# 1             Reims Collectables
# 2                Lyon Souveniers
# 3              Toys4GrownUps.com
# 4       Corporate Gift Ideas Co.
#                   ...
# 2818       Euro Shopping Channel
# 2819     Oulu Toy Supplies, Inc.
# 2820       Euro Shopping Channel
# 2821                Alpha Cognac
# 2822           Gifts4AllAges.com
# Name: CUSTOMERNAME, Length: 2823, dtype: object

# %% [markdown]
# **4. ¿Qué cantidad de datos tiene el DataFrame? Imprime el resultado indicando el número de filas y columnas**

# %%
dfventas.shape
# Out:
# (2823, 25)

# %% [markdown]
# **5. ¿Cuántas columnas tiene el DataFrame? ¿Lista los nombres de las columnas?**

# %%
dfventas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# **6. Verifica el número de observaciones no faltantes usando**`.tail()`**:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Podemos observar el número de observaciones non-null presentes en el número de entradas con el siguiente código

# %% [markdown]
# **7. Verifica la suma de valores faltantes por columna**

# %%
# Escribe tu código aquí

# %% [markdown]
# **8. Veamos el tipo de datos por columna. Escribe el nombre de al menos 3 características/variables tipo entero**

# %%
# Escribe tu código aquí

# %% [markdown]
# **9. Veamos una descripción de los valores de las columnas numéricas del DataFrame de forma transpuesta**

# %%
# Escribe tu código aquí

# %% [markdown]
# **10. Podemos observar que columna `ORDERDATE` es de tipo *object*, que generalmente se refiere al tipo `str` o cadena de texto. Conviértelos al tipo correcto**

# %%
# Escribe tu código aquí

# %% [markdown]
# **11. Haz la siguiente selección de datos utilizando sentencias condicionales:**

# %%
# Filtra las ordenes con ventas mayores a $2,000


# Selecciona los paises donde se han realizado ordenes


# Selecciona el número de productos únicos


# Selecciona las ciudades de USA donde se han realizado ordenes

# %% [markdown]
# **12. Haz una selección usando múltiples condiciones**

# %%
# Filtra los planes que fueron cancelados en el año 2014

# %% [markdown]
# **13. Agrupa los datos del DataFrame por país**

# %%
# Muestra el resultado de la agrupación para las primeras 16 filas usando head

# %% [markdown]
# **14. Veamos el valor promedio de las órdenes por país**

# %%
# Escribe tu código aquí

# %% [markdown]
# **15. Veamos el número de productos por tipo**

# %%
# Escribe tu código aquí

# %% [markdown]
# **16. Ordena por la fecha de orden de forma descendente**

# %%
# Escribe tu código aquí

# %% [markdown]
# -------
